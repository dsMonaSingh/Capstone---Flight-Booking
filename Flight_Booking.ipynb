# %% [markdown]
# # Problem Statement

# %% [markdown]
# The objective is to analyze the flight
# booking dataset obtained from a
# platform which is used to book flight
# tickets. A thorough study of the data
# will aid in the discovery of valuable
# insights that will be of enormous
# value to passengers. Apply EDA,
# statistical methods and Machine
# learning algorithms in order to get
# meaningful information from it.

# %% [markdown]
# # Dataset Information

# %% [markdown]
# Flight booking price prediction dataset contains around 3 lacs records
# with 11 attributes

# %% [markdown]
# # Importing the Libraries

# %%
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('Flight_Booking.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  days_left  price
# 0          Night           Mumbai  Economy      2.17          1   5953
# 1        Morning           Mumbai  Economy      2.33          1   5953
# 2  Early_Morning           Mumbai  Economy      2.17          1   5956
# 3      Afternoon           Mumbai  Economy      2.25          1   5955
# 4        Morning           Mumbai  Economy      2.33          1   5955

# %%
df = df.drop(columns='Unnamed: 0')
df.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300153 non-null  object
#  1   flight            300153 non-null  object
#  2   source_city       300153 non-null  object
#  3   departure_time    300153 non-null  object
#  4   stops             300153 non-null  object
#  5   arrival_time      300153 non-null  object
#  6   destination_city  300153 non-null  object
#  7   class             300153 non-null  object
#  8   duration          300153 non-null  float64
#  9   days_left         300153 non-null  int64
#  10  price             300153 non-null  int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 25.2+ MB

# %%
df.shape
# Out:
# (300153, 11)

# %%
df.describe()
# Out:
#             duration      days_left          price
# count  300153.000000  300153.000000  300153.000000
# mean       12.221021      26.004751   20889.660523
# std         7.191997      13.561004   22697.767366
# min         0.830000       1.000000    1105.000000
# 25%         6.830000      15.000000    4783.000000
# 50%        11.250000      26.000000    7425.000000
# 75%        16.170000      38.000000   42521.000000
# max        49.830000      49.000000  123071.000000

# %% [markdown]
# # Checking the Missing Values

# %%
df.isnull().sum()
# Out:
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %% [markdown]
# # Data Visulization ( airline vs price)

# %%
plt.figure(figsize=(10,8))
sns.lineplot(x = df['airline'],y= df['price'])
plt.title('Airline Vs Price')
plt.xlabel('Airline')
plt.ylabel("price")
plt.show()

# %% [markdown]
# # Data Visulization ( Days left for Departure vs price)

# %%
plt.figure(figsize=(10,8))
sns.lineplot(x = df['days_left'],y= df['price'],color = 'maroon')
plt.title('Days left for Departure  Vs Price')
plt.xlabel('Days left for Departure')
plt.ylabel("price")
plt.show()

# %% [markdown]
# conclusion := The price of the ticket increases as the days left for depature decreases

# %% [markdown]
# # Data Visulization barplot (airline vs price)

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = df['airline'],y= df['price'])
# Out:
# <Axes: xlabel='airline', ylabel='price'>

# %% [markdown]
# # Data Visulization barplot (class vs price according to airline)

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = df['class'],y= df['price'],hue= df['airline'])
# Out:
# <Axes: xlabel='class', ylabel='price'>

# %% [markdown]
# Conclusion:= Range of price of all the flights of Economy and Business class

# %% [markdown]
# # Data Visulization barplot (days lef for Departure vs price according to source city and destination)

# %%
plt.figure(figsize=(10,8))
plt.subplot(2,2,1)
sns.lineplot(x = df['days_left'],y= df['price'],hue= df['source_city'])
plt.subplot(2,2,2)
sns.lineplot(x = df['days_left'],y= df['price'],hue= df['destination_city'])
plt.show()

# %% [markdown]
# # Data Visualization of categorical features with countplot

# %% [markdown]
#  Data Visulization thorugh the countplot(airline,source_city,departure_time,stops,arrivaltime,departure,class )

# %%
plt.figure(figsize=(15,25))

plt.subplot(4,2,1)
sns.countplot(x= df['airline'])
plt.title("Frequency of Airline")

plt.subplot(4,2,2)
sns.countplot(x= df['source_city'])
plt.title("Frequency of source_city")

plt.subplot(4,2,3)
sns.countplot(x= df['departure_time'])
plt.title("Frequency of departure_time")

plt.subplot(4,2,4)
sns.countplot(x= df['stops'])
plt.title("Frequency of stops")

plt.subplot(4,2,5)
sns.countplot(x= df['arrival_time'])
plt.title("Frequency of arrival_time")


plt.subplot(4,2,6)
sns.countplot(x= df['destination_city'])
plt.title("Frequency of destination_city")

plt.subplot(4,2,7)
sns.countplot(x= df['class'])
plt.title("Frequency of class")

plt.show()

# %% [markdown]
# # LABEL ENCODING

# %% [markdown]
# Perorming One Hot Encoding for categorical features of a
# dataframe

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df.info()

# labeltranform means we have to chenge object datatype to int datatype nd h
#here fight data will be object because str data but other we have to change
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300153 non-null  object
#  1   flight            300153 non-null  object
#  2   source_city       300153 non-null  object
#  3   departure_time    300153 non-null  object
#  4   stops             300153 non-null  object
#  5   arrival_time      300153 non-null  object
#  6   destination_city  300153 non-null  object
#  7   class             300153 non-null  object
#  8   duration          300153 non-null  float64
#  9   days_left         300153 non-null  int64
#  10  price             300153 non-null  int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 25.2+ MB

# %%
df['airline'] = le.fit_transform(df['airline'])
df['source_city'] = le.fit_transform(df['source_city'])
df['departure_time'] = le.fit_transform(df['departure_time'])
df['stops'] = le.fit_transform(df['stops'])
df['arrival_time'] = le.fit_transform(df['arrival_time'])
df['destination_city'] = le.fit_transform(df['destination_city'])
df['class'] = le.fit_transform(df['class'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300153 non-null  int32
#  1   flight            300153 non-null  object
#  2   source_city       300153 non-null  int32
#  3   departure_time    300153 non-null  int32
#  4   stops             300153 non-null  int32
#  5   arrival_time      300153 non-null  int32
#  6   destination_city  300153 non-null  int32
#  7   class             300153 non-null  int32
#  8   duration          300153 non-null  float64
#  9   days_left         300153 non-null  int64
#  10  price             300153 non-null  int64
# dtypes: float64(1), int32(7), int64(2), object(1)
# memory usage: 17.2+ MB

# %% [markdown]
# # FEATURE SELELCTION

# %% [markdown]
# Plotting the correlation
# graph to see the
# correlation between
# features and dependent
# variable

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True , cmap='coolwarm')
plt.show()
# Out:
# C:\Users\diksh\AppData\Local\Temp\ipykernel_3488\1873049986.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True , cmap='coolwarm')

# %% [markdown]
# # Feature Selection

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list = []
for col in df.columns:
    if((df[col].dtype != 'object') & (col != 'price')):
        col_list.append(col)
        
X = df[col_list]
vif_data = pd.DataFrame()
vif_data['feature'] = X.columns
vif_data['VIF'] = [variance_inflation_factor(X.values , i)
                  for i in range(len(X.columns))]

print(vif_data)
# Out:
#             feature       VIF
# 0           airline  3.393124
# 1       source_city  2.927766
# 2    departure_time  2.779427
# 3             stops  1.426614
# 4      arrival_time  3.684550
# 5  destination_city  2.885337
# 6             class  2.849370
# 7          duration  4.113876
# 8         days_left  3.976790

# %% [markdown]
# # Feature Selection

# %%
df = df.drop(columns =['stops'])
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list = []
for col in df.columns:
    if((df[col].dtype != 'object') & (col != 'price')):
        col_list.append(col)
        
X = df[col_list]
vif_data = pd.DataFrame()
vif_data['feature'] = X.columns
vif_data['VIF'] = [variance_inflation_factor(X.values , i)
                  for i in range(len(X.columns))]

print(vif_data)
# Out:
#             feature       VIF
# 0           airline  3.370020
# 1       source_city  2.895803
# 2    departure_time  2.746255
# 3      arrival_time  3.632792
# 4  destination_city  2.857808
# 5             class  2.776721
# 6          duration  3.429344
# 7         days_left  3.950132

# %% [markdown]
# # LINEAR REGRESSION

# %% [markdown]
# Applying standardization and implementing Linear Regression Model to
# predict the price of a flight

# %%
X = df.drop(columns = ['price' ,'flight'])
Y = df['price']

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , Y_train , Y_test = train_test_split(X , Y , test_size = 0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train , Y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
difference = pd.DataFrame(np.c_[Y_test,y_pred], columns = ['Actual_value','predict_value'])
difference
# Out:
#        Actual_value  predict_value
# 0            7366.0    4673.755319
# 1           64831.0   51713.744720
# 2            6195.0    6610.897658
# 3           60160.0   55489.844234
# 4            6578.0    5120.342596
# ...             ...            ...
# 60026        5026.0    4960.777767
# 60027        3001.0    4693.865426
# 60028        6734.0    4974.962678
# 60029        5082.0    2729.650066
# 60030       66465.0   59638.748598
#
# [60031 rows x 2 columns]

# %% [markdown]
# Calculating r2 score,MAE, MAPE, MSE, RMSE. Root Mean square error(RMSE)
# of the Linear regression model is 7259.93 and Mean absolute percentage
# error(MAPE) is 34 percent. Lower the RMSE and MAPE better the model

# %%
from sklearn.metrics import r2_score
r2_score(Y_test , y_pred )
# Out:
# 0.897752737512321

# %%
from sklearn import metrics

mean_abs_error = metrics.mean_absolute_error(Y_test,y_pred)
mean_abs_error
# Out:
# 4468.426673542114

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(Y_test,y_pred)
# Out:
# 0.3476580461068189

# %%
mean_sq_error = metrics.mean_squared_error(Y_test,y_pred)
mean_sq_error
# Out:
# 52706651.33334209

# %%
root_mean_sq_error = np.sqrt(metrics.mean_squared_error(Y_test,y_pred))
root_mean_sq_error
# Out:
# 7259.934664536733

# %%
sns.distplot(Y_test , label = 'Actual')
sns.distplot(y_pred , label = 'Predicted')
plt.legend()
# Out:
# C:\Users\diksh\AppData\Local\Temp\ipykernel_3488\3875461676.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Y_test , label = 'Actual')
# C:\Users\diksh\AppData\Local\Temp\ipykernel_3488\3875461676.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
dt.fit(X_train , Y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = dt.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(Y_test , y_pred )
# Out:
# 0.974757031126925

# %%
from sklearn import metrics

mean_abs_error = metrics.mean_absolute_error(Y_test,y_pred)
mean_abs_error
# Out:
# 1216.520347820293

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(Y_test,y_pred)
# Out:
# 0.07690262294277206

# %%
mean_sq_error = metrics.mean_squared_error(Y_test,y_pred)
mean_sq_error
# Out:
# 13012302.986320958

# %%
root_mean_sq_error = np.sqrt(metrics.mean_squared_error(Y_test,y_pred))
root_mean_sq_error
# Out:
# 3607.2569892261567

# %%
sns.distplot(Y_test , label = 'Actual')
sns.distplot(y_pred , label = 'Predicted')
plt.legend()
# Out:
# C:\Users\diksh\AppData\Local\Temp\ipykernel_3488\3875461676.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Y_test , label = 'Actual')
# C:\Users\diksh\AppData\Local\Temp\ipykernel_3488\3875461676.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()
rfr.fit(X_train , Y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = rfr.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(Y_test , y_pred )
# Out:
# 0.9846006458530348

# %%
from sklearn import metrics

mean_abs_error = metrics.mean_absolute_error(Y_test,y_pred)
mean_abs_error
# Out:
# 1121.8810412173948

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(Y_test,y_pred)
# Out:
# 0.07347414211866107

# %%
mean_sq_error = metrics.mean_squared_error(Y_test,y_pred)
mean_sq_error
# Out:
# 7938094.087169881

# %%
root_mean_sq_error = np.sqrt(metrics.mean_squared_error(Y_test,y_pred))
root_mean_sq_error
# Out:
# 2817.4623488468983

# %%
sns.distplot(Y_test , label = 'Actual')
sns.distplot(y_pred , label = 'Predicted')
plt.legend()
# Out:
# C:\Users\diksh\AppData\Local\Temp\ipykernel_3488\3875461676.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Y_test , label = 'Actual')
# C:\Users\diksh\AppData\Local\Temp\ipykernel_3488\3875461676.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...
